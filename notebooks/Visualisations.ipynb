# %% [markdown]
# <table class="table table-bordered">
#     <tr>
#         <th style="text-align:center; vertical-align: middle; width:50%"><img src='https://www.np.edu.sg/images/default-source/default-album/img-logo.png'"></th>
#         <th style="text-align:center;"><h1>Agile DataOps</h1><h2>Assignment 2(Group) - Visualisations</h2><h3>AY2024/25 Semester</h3></th>
#     </tr>
# </table>

# %% [markdown]
# ![image.png](attachment:7ef94cfb-c854-4e85-b434-020eac6b8d1d.png)

# %% [markdown]
# For this chart, limiting the bars to the top 5 constructors allows me to emphasize the dominant teams in F1 history. Teams like Ferrari, Mercedes, and Red Bull consistently outperform others and are the focus of most fan and media attention. Including only these top teams makes the chart more meaningful, as their points reflect their success and legacy. Showing every constructor would dilute the significance of these powerhouses and make it harder to see their dominance clearly.

# %% [markdown]
# ![image.png](attachment:f56b0a36-e81e-40c9-ad84-76866aec859f.png)

# %% [markdown]
# This chart highlights the top-performing drivers in terms of total points. By showing only the top 5, I can focus on the greatest drivers in F1, such as Lewis Hamilton, Sebastian Vettel, and Max Verstappen. These drivers have consistently performed at the highest level, and their points showcase their skill and consistency. Including more drivers would make the chart less impactful, as lower-ranked drivers don’t contribute significantly to the bigger picture of F1’s competitive landscape.

# %% [markdown]
# ![image.png](attachment:e57ceae6-a424-4e50-8cb1-145b18c04f4e.png)

# %% [markdown]
# In the wins chart, limiting it to the top 5 drivers shows the most successful individuals in F1 history. Drivers like Lewis Hamilton and Michael Schumacher have an unparalleled number of wins, and focusing on them highlights their incredible achievements. Including drivers with fewer wins would overshadow the dominance of these legends. The goal is to highlight the best, and showing only the top 5 ensures the chart remains focused and relevant.

# %% [markdown]
# ![image.png](attachment:67c0f287-a5e7-4eda-b624-66e302c72e33.png)

# %% [markdown]
# This chart emphasizes podium finishes, which are a clear indicator of consistency and performance in F1. By limiting the bars to the top 5, I can showcase drivers like Lewis Hamilton, Michael Schumacher, and Sebastian Vettel, who have been the most consistent over their careers. Including more drivers would dilute the importance of their achievements and make the chart harder to interpret. The top 5 tells the story of F1’s most consistent podium finishers.

# %% [markdown]
# ![image.png](attachment:626e77f6-403c-4922-a842-5c4810b145ad.png)

# %% [markdown]
# In this chart, showing only the top 5 drivers highlights the best performers in that particular session. Drivers like Max Verstappen and Charles Leclerc often stand out in individual races, and focusing on the top 5 makes it easy to see who dominated that specific event. Adding more drivers would take away the focus from these key performers and make the chart cluttered, reducing its effectiveness in capturing the race’s highlights
